# %% [raw]
# Columns / Fields / Variables
# Rows / Records / Observations or Obs
#
# EDA
#
#     Metadata Inspection (Info about the structrue of the data)
#
#         Columns
#         How many Columns, Column Name, Order, Data types, Calculated columns...
#
#         type()
#         .shape, .columns, .dtypes, .nunique(), .count()
#         .info()
#
#      Data Inspection
#         Data,
#         Distributions,
#         Outliers, Missing, Groups / Bins, Filters, Duplicates, Sort, transformations etc.
#         corelations
#
#         .head(), .tail()
#         .describe()
#
# Data Combining:
#     Joins
#         pd.merge( left = , right = , how = , left_on = , right_on = , suffixes = , indicator = )
#
#     Append
#         .append( )
#         pd.concat( axis = 0 )
#
#     Concat
#         pd.concact( axis = 1 )
#
# Data Prep / Data Cleaning / Data Munging / Data Wrangling
#
#     functions
#         logical
#         aggregate: sum, min, max, count, std, var, p, q
#         date, time, datetime
#         text
#         number
#
#     Structure Based Changes
#         Subsetting - choosing perticular variables
#
#             Manual
#             [], .loc[:, ], iloc[:, ], .column_name
#
#             Conditional
#             .loc[:, condition/s ], .select_dtypes()
#
#         ReOrder the variables
#             [], .loc[:, ], iloc[:, ]
#
#         Calculated Variables
#             .assign(), .insert()
#             [new_var_name] =
#             .loc[:, new_var_name] =
#
#         Rename the variables
#             .rename( columns = {old:new, ....}, inplace = )
#             .columns = [list_of_new_var_names]
#
#         Drop the variables
#             .drop( columns = [], inplace = )
#
#         Data Type conversions
#
#             Data Type conversions:
#             .astype( new_data_type )
#
#             pd.to_numeric()
#             pd.to_datetime()
#
#             datetime.datetime.strftime()
#             str()
#             float()
#             int()
#             bool()
#
#             Type conversions:
#             list(), tuple(), dict(), set(), np.array(), pd.Series(), pd.DataFrame()
#
#
#     Data Based / Content based Changes
#         filters
#             manual
#             .head(), .tail()
#             [] - only slicers
#             .iloc[], .loc[]
#
#             conditional
#             [] - indexing
#             .loc[]
#
#         sorting
#             .sort_values( by = , ascending = , inplace = , ignore_index = , kind = )
#             .sort_index( axis = , inplace = , ascending =  )
#
#         duplicates
#             .drop_duplicates( subset = , keep = , inplace = , ignore_index = ) # drop the duplicates
#             .duplicated( subset = , keep = ) # Boolean
#
#         outliers
#             detection
#                 percentile: p1, p99
#                 iqr / boxplots: q1 - 1.5 * iqr, q3 + 1.5 * iqr
#                     iqr = q3 - q1
#                 std: mean +/- 2.5 * std
#
#                 .quantile(), .mean(), .std()
#
#             treatment
#                 .clip( lower = , upper = , inplace = )
#
#         missing values
#             NaN, NaT, None
#
#             detection
#                 .isna(), .isnull(), .notna(), .notnull(), .count(), .shape[0]
#                 %age of missings in each variable
#
#             treatment
#                 .dropna( axis = , subset = , how = , thresh = )
#                 .fillna()
#
#         categorical vs continuous
#             text, date/time, boolean - categorical
#             numbers - integers / decimals: categorical or continuous
#
#         group and bins
#             pd.cut() - bins, groups: only on numeric data
#             pd.qcut() - groups: only on numeric data
#             np.where() - logical groups: can work on any data or combinations too
#
#         data summaries
#             .groupby(), .sum(), .mean(), ....., .agg() - long table
#             .pivot() - cross table
#
#             .pivot_table() -  to create long, wide or cross table
#
#             pd.crosstab() - only to create cross table

# %% [markdown]
# ## vizualisation

# %%
## understanding the data
## pie, histograms, column, stacked column charts, kpi carts,
## heatmap, treemap, scatter plots, maps

# %% [markdown]
# In data science, you will be creating for 4 basic purposes
#
# 1. Data distributions
# 2. Trends
# 3. compositions / proportions
# 4. Relationships
#
#
# Two different kinds of variables in structured data.
#
# 1. categorical variables
# 2. continous variables
#
#
# Univariate analysis
#
#     1. categorical variables
#         pie chart, column chart, bar chart
#
#     2. continuous variables
#         histograms, boxplots
#
#
# Bivariate analysis
#     1. categorical vs categorical
#
#         crosstab, heatmaps
#
#
#     2. continuous vs continuous
#
#         scatter plots, correlations, heatmaps
#
#
#
#     3. categorical vs continuous
#         bar, horizontal bar, column charts, pie charts, doughnut charts
#
#
#
#
#
# Multivariate analysis
#
#     stacked column charts

# %% [markdown]
# ## libraries for vizualisation
#
# 1. matplotlib
# 2. pandas
# 3. seaborn ( statistical charts and analysis )
#
#
# plotly, bokeh, dash, ......

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

## used to set the setting in matplotlib
## magic function
# %matplotlib inline

# %%
stores = pd.read_csv('d:/data/stores.csv')

# %%
stores.head()
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110            3.90       2.620
# 1         60       160.0              110            3.90       2.875
# 2         40       108.0               93            3.85       2.320
# 3         60       258.0              110            3.08       3.215
# 4         80       360.0              175            3.15       3.440
#
#    ProfitPercust  OwnStore  Dummy  OnlinePresence  Tenure  StoreSegment
# ...

# %%
plt?

# %% [markdown]
# ## Univariate analysis
#
# Continuous variables
#
#     histograms, boxplots

# %%
stores.select_dtypes('number').head(2)
# Out:
#    OperatingCost  Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  \
# 0           21.0         60       160.0              110             3.9
# 1           21.0         60       160.0              110             3.9
#
#    BasketSize  ProfitPercust  OwnStore  Dummy  OnlinePresence  Tenure  \
# 0       2.620          16.46         0    NaN               1       4
# 1       2.875          17.02         0    NaN               1       4
#
#    StoreSegment
# 0             4
# 1             4

# %%
## using pandas

#plt.figure(figsize=(12, 5))
plt.figure(figsize=(12, 5))
stores.TotalSales.plot(kind='hist')
plt.title("Distribution of Total Sales")
plt.grid(True)
plt.xlabel("TotalSales")
plt.show()   ## this is like the print statement for charts in python

# %%
plt.figure()
plt.axes()
# Out:
# <AxesSubplot:>

# %%
stores.TotalSales
# Out:
# 0     160.0
# 1     160.0
# 2     108.0
# 3     258.0
# 4     360.0
# 5     225.0
# 6     360.0
# 7     146.7
# 8     140.8
# 9     167.6
# 10    167.6
# 11    275.8
# 12    275.8
# 13    275.8
# 14    472.0
# 15    460.0
# 16    440.0
# 17     78.7
# 18     75.7
# 19     71.1
# 20    120.1
# 21    318.0
# 22    304.0
# 23    350.0
# 24    400.0
# 25     79.0
# 26    120.3
# 27     95.1
# 28    351.0
# 29    145.0
# 30    301.0
# 31    121.0
# Name: TotalSales, dtype: float64

# %%
## using matplotlib

#plt.figure(figsize=(12, 8))
#plt.axes()
plt.hist(stores.TotalSales)
plt.ylabel('Frequency')
plt.xlabel('TotalSales')
plt.title('Distribution of TotalSales')
#plt.text(225, 5, 'This is text')
plt.savefig('d:/python_new/fig2.png')
plt.show()

# %%
## using seaborn

sns.histplot(x=stores.TotalSales, bins=10)
# Out:
# <AxesSubplot:xlabel='TotalSales', ylabel='Count'>

# %%
sns.histplot(y=stores.TotalSales)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='TotalSales'>

# %%
## boxplots

stores.TotalSales.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
## using matplotlib

plt.boxplot(stores.TotalSales)
plt.show()

# %%
sns.boxplot(x=stores.TotalSales)
# Out:
# <AxesSubplot:xlabel='TotalSales'>

# %%
sns.boxplot(y=stores.TotalSales)
# Out:
# <AxesSubplot:ylabel='TotalSales'>

# %%
print(stores.OperatingCost.min())
print(stores.OperatingCost.max())
# Out:
# 10.4
# 33.9

# %%
q1 = stores.OperatingCost.quantile(0.25)
q3 = stores.OperatingCost.quantile(0.75)

iqr = q3 - q1

upper = q3 + 1.5*iqr
lower = q1 - 1.5*iqr

# %%
lower
# Out:
# 4.362500000000001

# %%
upper
# Out:
# 33.8625

# %%
sns.boxplot(y=stores.OperatingCost)
# Out:
# <AxesSubplot:ylabel='OperatingCost'>

# %%
## Univariate

## Categorical variable

# %%
stores.StoreType.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
stores.StoreType.value_counts().plot(kind='barh', color=[137/255, 235/255, 52/255])
# Out:
# <AxesSubplot:>

# %%
## colors

sns.countplot(x=stores.StoreType)
# Out:
# <AxesSubplot:xlabel='StoreType', ylabel='count'>

# %%
stores.StoreType.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='StoreType'>

# %% [markdown]
# ## Bivariate analysis

# %%
## Categorical vs Categorical

stores[['StoreType', 'Location']]
# Out:
#        StoreType Location
# 0   Electronincs    Delhi
# 1        Apparel    Delhi
# 2   Super Market    Delhi
# 3   Super Market    Delhi
# 4   Super Market    Delhi
# 5        Apparel    Delhi
# 6        Apparel    Delhi
# 7   Electronincs    Delhi
# 8   Electronincs  Chennai
# 9        Apparel  Chennai
# 10  Super Market  Chennai
# 11  Super Market  Chennai
# 12  Super Market  Chennai
# 13       Apparel  Chennai
# 14       Apparel  Chennai
# 15  Electronincs  Chennai
# 16  Electronincs   Mumbai
# 17       Apparel   Mumbai
# 18  Super Market   Mumbai
# 19  Super Market   Mumbai
# 20  Super Market   Mumbai
# 21       Apparel   Mumbai
# 22       Apparel   Mumbai
# 23  Electronincs   Mumbai
# 24  Electronincs  Kolkata
# 25       Apparel  Kolkata
# 26  Super Market  Kolkata
# 27  Super Market  Kolkata
# 28  Super Market  Kolkata
# 29       Apparel  Kolkata
# 30       Apparel  Kolkata
# 31  Electronincs  Kolkata

# %%
pd.crosstab(stores.StoreSegment, stores.Location)
# Out:
# Location      Chennai  Delhi  Kolkata  Mumbai
# StoreSegment
# 1                   0      3        1       3
# 2                   1      2        4       3
# 3                   3      0        0       0
# 4                   4      3        3       2

# %%
## heatmap

plt.figure(figsize=(12, 5))
sns.heatmap(pd.crosstab(stores.StoreSegment, stores.Location), annot=True)
plt.savefig('d:/python_new/fig3.png')
plt.show()

# %%
## continuous vs continuous

## scatter plot

## TotalSales vs OperatingCost

# %%
## using pandas

stores.plot(kind='scatter', x='TotalSales', y='OperatingCost')
# Out:
# <AxesSubplot:xlabel='TotalSales', ylabel='OperatingCost'>

# %%
stores[['TotalSales', 'OperatingCost']].plot(kind='scatter', x='TotalSales', y='OperatingCost', s=40, marker='^', color='red')
# Out:
# <AxesSubplot:xlabel='TotalSales', ylabel='OperatingCost'>

# %%
## using matplotlib

plt.scatter(stores.OperatingCost, stores.TotalSales)
plt.show()

# %%
sns.scatterplot(x=stores.OperatingCost, y=stores.TotalSales, hue=stores.Location)
plt.show()

# %%
## regplot

sns.regplot(x=stores.OperatingCost, y=stores.TotalSales)
# Out:
# <AxesSubplot:xlabel='OperatingCost', ylabel='TotalSales'>

# %%
## pairplot

sns.pairplot( stores.select_dtypes('float').drop(columns='Dummy') )

# %%
## 

## .corr()

# %%
sns.heatmap( stores.select_dtypes('float').drop(columns='Dummy').corr(), cmap='Blues' )
# Out:
# <AxesSubplot:>

# %%
## -1 and 1
## -1 perfect inverse relationship
## 1 perfect positive relationship
stores.select_dtypes('float').drop(columns='Dummy').head(2)
# Out:
#    OperatingCost  TotalSales  AcqCostPercust  BasketSize  ProfitPercust
# 0           21.0       160.0             3.9       2.620          16.46
# 1           21.0       160.0             3.9       2.875          17.02

# %%
## Q: plot the histogram of all the continuous variables

stores.select_dtypes('float').drop(columns='Dummy')
# Out:
#     OperatingCost  TotalSales  AcqCostPercust  BasketSize  ProfitPercust
# 0            21.0       160.0            3.90       2.620          16.46
# 1            21.0       160.0            3.90       2.875          17.02
# 2            22.8       108.0            3.85       2.320          18.61
# 3            21.4       258.0            3.08       3.215          19.44
# 4            18.7       360.0            3.15       3.440          17.02
# 5            18.1       225.0            2.76       3.460          20.22
# 6            14.3       360.0            3.21       3.570          15.84
# 7            24.4       146.7            3.69       3.190          20.00
# 8            22.8       140.8            3.92       3.150          22.90
# 9            19.2       167.6            3.92       3.440          18.30
# 10           17.8       167.6            3.92       3.440          18.90
# 11           16.4       275.8             NaN       4.070          17.40
# ...

# %%
def plot1(x):
    print(f'Distribution of {x.name}')
    sns.histplot(x=x)
    plt.show()

# %%
stores.select_dtypes('float').drop(columns='Dummy').apply(lambda x: plot1(x))
# Out:
# Distribution of OperatingCost
# Distribution of TotalSales
# Distribution of AcqCostPercust
# Distribution of BasketSize
# Distribution of ProfitPercust
# OperatingCost     None
# TotalSales        None
# AcqCostPercust    None
# BasketSize        None
# ProfitPercust     None
# dtype: object

# %%
## categorical vs continuous

## column charts, bar charts

# %%
## TotalSales by each StoreType graphically

stores.groupby('StoreType').TotalSales.sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='StoreType'>

# %%
## clustered column charts

# %%
## Plot the TotalSales by each location. Also, segregate the bars based on StoreType

# %%
summ = pd.pivot_table(data=stores, index='Location', columns='StoreType', values='TotalSales', aggfunc='sum')

# %%
summ.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
summ.plot(kind='bar', stacked=True, ylim=(50, 10000))
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
## pd.concat()

# %%
pos1 = pd.read_csv('d:/data/POS_Q1.csv')
pos2 = pd.read_csv('d:/data/POS_Q2.csv')
pos3 = pd.read_csv('d:/data/POS_Q3.csv')
pos4 = pd.read_csv('d:/data/POS_Q4.csv')

# %%
pos1
# Out:
#             Date  Configuration Customer Postcode Store Postcode  \
# 0  01-01-13 0:01            163          EC4V 5BH        SE1 2BN
# 1  01-01-13 0:02            320           SW4 0JL       SW12 9HD
# 2  01-01-13 0:04             23          EC3V 1LR         E2 0RY
# 3  01-01-13 0:04            169          SW1P 3AU        SE1 2BN
# 4  01-01-13 0:06            365          EC4V 4EG       SW1V 4QQ
#
#    Retail Price  month
# 0           455      1
# 1           545      1
# 2           515      1
# 3           395      1
# 4           585      1

# %%
pos2
# Out:
#             Date  Configuration Customer Postcode Store Postcode  \
# 0  04-01-13 0:00            216           KT2 7PX         W4 3PH
# 1  04-01-13 0:05            317          EC3N 2AE       SW1P 3AU
# 2  04-01-13 0:32            176           W1T 1HH        NW5 2QH
# 3  04-01-13 0:43            176           SE3 0QJ        SE8 3JD
# 4  04-01-13 0:47             61           W1W 6DL       SW1V 4QQ
# 5  04-01-13 0:48            163           NW1 4BX       SW1P 3AU
# 6  04-01-13 0:56            302           E14 0BB        SE1 2BN
# 7  04-01-13 0:58             21           SE1 8SW       SW1V 4QQ
# 8  04-01-13 1:00             73           W1U 5JN       SW1P 3AU
# 9  04-01-13 1:03            317            W8 7SR        W10 6HQ
#
#    Retail Price  month
# 0           505      4
# 1           520      4
# 2           450      4
# 3           450      4
# 4           430      4
# 5           440      4
# 6           445      4
# 7           440      4
# 8           395      4
# ...

# %%
pos3
# Out:
#              Date  Configuration Customer Postcode Store Postcode  \
# 0   07-01-13 0:00             23            E4 9PB         E7 8NW
# 1   07-01-13 0:06             55          WC2A 2HF       SW1V 4QQ
# 2   07-01-13 0:10            222           W1K 6JG        W10 6HQ
# 3   07-01-13 0:11            595          EC3M 7HR        SE1 2BN
# 4   07-01-13 0:13              8           W1H 5HT       SW1V 4QQ
# 5   07-01-13 0:13            323           SE1 2PF        SE1 2BN
# 6   07-01-13 0:13            628           KT2 5EB        KT2 5AU
# 7   07-01-13 0:14            465          SW1H 9LA        SE1 2BN
# 8   07-01-13 0:14            177           SW7 4SS        W10 6HQ
# 9   07-01-13 0:14            369          EC1R 1UY        SE1 2BN
# 10  07-01-13 0:15            607          SE24 0NG       SW1P 3AU
# 11  07-01-13 0:15            606            N7 9BL         E2 0RY
# 12  07-01-13 0:17            532           W1W 5QU       SW1V 4QQ
# ...

# %%
pos4
# Out:
#             Date  Configuration Customer Postcode Store Postcode  \
# 0  10-01-13 0:02            579          EC1V 2QH       SW1P 3AU
# 1  10-01-13 0:05            523            E3 4QS         E2 0RY
# 2  10-01-13 0:07            574          EC1M 5NA        NW5 2QH
# 3  10-01-13 0:08             62            N7 6PN        N17 6QA
# 4  10-01-13 0:11            295          EC1N 8QS       SW1P 3AU
# 5  10-01-13 0:11            100           SE1 1NA        SE1 2BN
# 6  10-01-13 0:11            475          EC1V 9NU       SW1P 3AU
#
#    Retail Price  month
# 0           510     10
# 1           550     10
# 2           660     10
# 3           320     10
# 4           545     10
# 5           510     10
# 6           520     10

# %%
pd.concat([pos1, pos2, pos3, pos4])
# Out:
#              Date  Configuration Customer Postcode Store Postcode  \
# 0   01-01-13 0:01            163          EC4V 5BH        SE1 2BN
# 1   01-01-13 0:02            320           SW4 0JL       SW12 9HD
# 2   01-01-13 0:04             23          EC3V 1LR         E2 0RY
# 3   01-01-13 0:04            169          SW1P 3AU        SE1 2BN
# 4   01-01-13 0:06            365          EC4V 4EG       SW1V 4QQ
# 0   04-01-13 0:00            216           KT2 7PX         W4 3PH
# 1   04-01-13 0:05            317          EC3N 2AE       SW1P 3AU
# 2   04-01-13 0:32            176           W1T 1HH        NW5 2QH
# 3   04-01-13 0:43            176           SE3 0QJ        SE8 3JD
# 4   04-01-13 0:47             61           W1W 6DL       SW1V 4QQ
# 5   04-01-13 0:48            163           NW1 4BX       SW1P 3AU
# 6   04-01-13 0:56            302           E14 0BB        SE1 2BN
# 7   04-01-13 0:58             21           SE1 8SW       SW1V 4QQ
# ...

# %%
pos1.rename(columns={'month': 'Month'}, inplace=True)

# %%
float_vars = stores.select_dtypes('float')

# %%
float_vars
# Out:
#     OperatingCost  TotalSales  AcqCostPercust  BasketSize  ProfitPercust  \
# 0            21.0       160.0            3.90       2.620          16.46
# 1            21.0       160.0            3.90       2.875          17.02
# 2            22.8       108.0            3.85       2.320          18.61
# 3            21.4       258.0            3.08       3.215          19.44
# 4            18.7       360.0            3.15       3.440          17.02
# 5            18.1       225.0            2.76       3.460          20.22
# 6            14.3       360.0            3.21       3.570          15.84
# 7            24.4       146.7            3.69       3.190          20.00
# 8            22.8       140.8            3.92       3.150          22.90
# 9            19.2       167.6            3.92       3.440          18.30
# 10           17.8       167.6            3.92       3.440          18.90
# 11           16.4       275.8             NaN       4.070          17.40
# ...

# %%
categorical_vars = stores.select_dtypes('object')

# %%
categorical_vars
# Out:
#    StoreCode         StoreName     StoreType Location
# 0     STR101  Electronics Zone  Electronincs    Delhi
# 1     STR102      Apparel Zone       Apparel    Delhi
# 2     STR103       Super Bazar  Super Market    Delhi
# 3     STR104      Super Market  Super Market    Delhi
# 4     STR105     Central Store  Super Market    Delhi
# 5     STR106      Apparel Zone       Apparel    Delhi
# 6     STR107     Fashion Bazar       Apparel    Delhi
# 7     STR108     Digital Bazar  Electronincs    Delhi
# 8     STR109  Electronics Zone  Electronincs  Chennai
# 9     STR110      Apparel Zone       Apparel  Chennai
# 10    STR111       Super Bazar  Super Market  Chennai
# 11    STR112      Super Market  Super Market  Chennai
# 12    STR113     Central Store  Super Market  Chennai
# 13    STR114      Apparel Zone       Apparel  Chennai
# 14    STR115     Fashion Bazar       Apparel  Chennai
# 15    STR116     Digital Bazar  Electronincs  Chennai
# ...

# %%
pd.concat([categorical_vars, float_vars], axis=1)
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1     STR102      Apparel Zone       Apparel    Delhi           21.0
# 2     STR103       Super Bazar  Super Market    Delhi           22.8
# 3     STR104      Super Market  Super Market    Delhi           21.4
# 4     STR105     Central Store  Super Market    Delhi           18.7
# 5     STR106      Apparel Zone       Apparel    Delhi           18.1
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 7     STR108     Digital Bazar  Electronincs    Delhi           24.4
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 11    STR112      Super Market  Super Market  Chennai           16.4
# 12    STR113     Central Store  Super Market  Chennai           17.3
# ...

# %%
## stats

## What is stats
